# %%
pip install plotly

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from IPython.display import display, Markdown

# %%
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)

# %%
# Substitua 'seu_arquivo.csv' pelo caminho do seu arquivo CSV
caminho_do_arquivo = '/home/carolcardoso/git/dados/Dados SIAPE/202311_Cadastro.csv'

# Carregando o arquivo CSV em um DataFrame do Pandas
df_cadastro = pd.read_csv(caminho_do_arquivo, encoding='iso-8859-1', sep=';')
# Out:
# /tmp/ipykernel_14786/2812195543.py:5: DtypeWarning: Columns (2,5,7,9,34,36,37,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cadastro = pd.read_csv(caminho_do_arquivo, encoding='iso-8859-1', sep=';')

# %%
display("função head do pandas")

display (df_cadastro.info())
# Out:
# 'função head do pandas'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748596 entries, 0 to 748595
# Data columns (total 43 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Id_SERVIDOR_PORTAL                    748596 non-null  int64
#  1   NOME                                  748596 non-null  object
#  2   CPF                                   712000 non-null  object
#  3   MATRICULA                             748596 non-null  object
#  4   DESCRICAO_CARGO                       748596 non-null  object
#  5   CLASSE_CARGO                          569395 non-null  object
#  6   REFERENCIA_CARGO                      712000 non-null  float64
#  7   PADRAO_CARGO                          441081 non-null  object
#  8   NIVEL_CARGO                           712000 non-null  float64
#  9   SIGLA_FUNCAO                          748596 non-null  object
# ...

# %%
def gerar_grafico_quantidade_valores_unicos_coluna(df, coluna, numero_elementos):
    # Calcular a contagem de valores únicos na coluna
    df_contagem = df[coluna].value_counts().reset_index()
    df_contagem.columns = [coluna, 'Quantidade']

    # Criar um gráfico de barras
    ax = df_contagem.head(numero_elementos).plot(kind='bar', x=coluna, y='Quantidade')

    # Adicionar rótulos e título
    plt.xlabel(coluna)
    plt.ylabel('Quantidade de registros únicos')
    plt.title(f'Contagem de valores únicos em {coluna}')

    # Adicionar rótulos de dados (valores) em cada barra
    for p in ax.patches:
        ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='baseline')

    # Mostrar o gráfico
    plt.show()

    

def gerar_graficos_dataframe(df):
    
    for coluna in df.columns:
    
        display(Markdown(f'# Informações: {coluna}'))
        
        elementos_unicos = df[coluna].nunique()
        
        texto_elementos_unicos = f'Quantidade de elementos únicos: {elementos_unicos}'
        
        display(texto_elementos_unicos)

        if elementos_unicos == 0:

            display (f"ATENÇÃO: Número de elementos únicos é igual a zero")
        
        elif elementos_unicos < 1000:
            
            gerar_grafico_quantidade_valores_unicos_coluna (df, coluna, 10)
    
        else:
            
            display (f"ATENÇÃO: Número de elementos únicos não pode ser exibido em gráfico")

# %% [markdown]
# # Julia

# %%
df_cadastro[        
    df_cadastro['NOME'].str.lower().str.startswith('julia') &
    df_cadastro['REGIME_JURIDICO'].str.contains('est', case=False, na=False) & 
    df_cadastro['ORG_LOTACAO'].str.contains('fazenda', case=False, na=False)
    ]
# Out:
#         Id_SERVIDOR_PORTAL                              NOME             CPF  \
# 364025           311855507              JULIA AGUIAR FONSECA  ***.246.788-**
# 364038           311800308               JULIA ALVES BARBOSA  ***.134.886-**
# 364406           313673580                        JULIA FAVA  ***.528.178-**
# 364417           312972892                    JULIA FERRANTI  ***.124.198-**
# 364467           312281537           JULIA GERMANO EMANUELLI  ***.165.688-**
# 364558           311967749      JULIA LEASTRO DA CRUZ AGUIAR  ***.924.551-**
# 364677           311594642      JULIA MARQUES ROMAO DE SOUZA  ***.720.693-**
# 364809           310882490  JULIA PEREIRA MARINHO DOS SANTOS  ***.125.861-**
# 364856           311853572  JULIA REZENDE PEREIRA DOS SANTOS  ***.630.058-**
# 364884           310072939             JULIA RODRIGUES PAIVA  ***.607.068-**
# 364952           310247644                JULIA SOARES SILVA  ***.607.951-**
# ...

# %%
nome = "nome_do_arquivo_202312.csv"
display(f'AnoMes: {nome[-10:-4]}')
display(f'Ano: {nome[-10:-6]}')
display(f'Mes: {nome[-6:-4]}')

ano = nome[-10:-6]
display(int(ano))
# Out:
# 'AnoMes: 202312'
# 'Ano: 2023'
# 'Mes: 12'
# 2023

# %% [markdown]
# # Estagiários UORG_EXERCICIO RFB ORG_LOTACAO fazenda
# ## ATENÇÃO: UORG_LOTACAO para estagiários é sempre Inválido

# %%
df_estagiarios_rfb = df_cadastro[            
    df_cadastro['REGIME_JURIDICO'].str.contains('est', case=False, na=False) & 
    df_cadastro['UORG_EXERCICIO'].str.contains('rfb', case=False, na=False) & 
    df_cadastro['ORG_LOTACAO'].str.contains('fazenda', case=False, na=False)
    ]

# %%
df_estagiarios_rfb.value_counts("UORG_EXERCICIO")
# Out:
# UORG_EXERCICIO
# ALF/FOZ/ALF RFB EM FOZ DO IGUACU            6
# DRF/UBL/DELEGACIA RFB EM UBERLANDIA         3
# IRF/CHU/INSPETORIA RFB EM CHUI              3
# DRF/GVS/DELEGACIA RFB GOV VALADARES         2
# DRF/GUA/DELEGACIA RFB EM GUARULHOS          2
# ARF/SAS/AGENCIA RFB STO ANTONIO SUDOESTE    2
# DRF/JOA/DELEGACIA RFB EM JOACABA            2
# ARF/TAN/AGENCIA RFB EM TANGARA DA SERRA     2
# ARF/SUZ/AGENCIA RFB EM SUZANO               2
# ARF/CFO/AGENCIA RFB EM CABO FRIO            2
# DRF/OSA/DELEGACIA RFB EM OSASCO             2
# DRF/PTG/DELEGACIA RFB EM PONTA GROSSA       2
# ARF/PET/AGENCIA RFB EM PETROPOLIS           2
# ARF/BPI/AGENCIA RFB EM BARRA DO PIRAI       2
# IRF/CAC/INSPETORIA DA RFB EM CACERES        2
# ARF/SIN/AGENCIA RFB EM SINOP                2
# ARF/SGO/AGENCIA RFB EM SAO GONCALO          2
# ARF/RBT/AGENCIA RFB EM RIO BONITO           2
# ALF/DCA/ALF RFB EM DIONISIO CERQUEIRA       2
# ALF/COR/ALF RFB EM CORUMBA                  2
# ...

# %% [markdown]
# # TODOS Receita Federal

# %%
df_uorg_lotacao_rfb = df_cadastro[        
    df_cadastro['UORG_LOTACAO'].str.contains('rfb', case=False, na=False)]

# %%
gerar_graficos_dataframe(df_uorg_lotacao_rfb)
# Out:
# # Informações: Id_SERVIDOR_PORTAL
# 'Quantidade de elementos únicos: 15060'
# 'ATENÇÃO: Número de elementos únicos não pode ser exibido em gráfico'
# # Informações: NOME
# 'Quantidade de elementos únicos: 15050'
# 'ATENÇÃO: Número de elementos únicos não pode ser exibido em gráfico'
# # Informações: CPF
# 'Quantidade de elementos únicos: 14915'
# 'ATENÇÃO: Número de elementos únicos não pode ser exibido em gráfico'
# # Informações: MATRICULA
# 'Quantidade de elementos únicos: 36'
# # Informações: DESCRICAO_CARGO
# 'Quantidade de elementos únicos: 116'
# # Informações: CLASSE_CARGO
# 'Quantidade de elementos únicos: 7'
# # Informações: REFERENCIA_CARGO
# 'Quantidade de elementos únicos: 2'
# # Informações: PADRAO_CARGO
# 'Quantidade de elementos únicos: 10'
# # Informações: NIVEL_CARGO
# 'Quantidade de elementos únicos: 2'
# # Informações: SIGLA_FUNCAO
# 'Quantidade de elementos únicos: 7'
# # Informações: NIVEL_FUNCAO
# 'Quantidade de elementos únicos: 20'
# # Informações: FUNCAO
# ...

# %% [markdown]
# # Estagiários Receita Federal

# %%
df_estagio_uorg_lotacao_rfb = df_uorg_lotacao_rfb[
    df_uorg_lotacao_rfb['REGIME_JURIDICO'].str.contains('est', case=False, na=False)]

# %%
df_uorg_lotacao_rfb.sample(5)
# Out:
#         Id_SERVIDOR_PORTAL                             NOME             CPF  \
# 554200           311810008            PAULO IUKIHARU TABATA  ***.091.808-**
# 89831            310518605  BRANCA CRISTINA ESRANI DA PENHA  ***.173.131-**
# 498180           312609355                 MARIO LUCIO ROSA  ***.193.597-**
# 286758           310500642             HELOISA HELENA CONDE  ***.962.318-**
# 48711            310405541          ANA PAULA RAMOS PEREIRA  ***.260.268-**
#
#        MATRICULA                           DESCRICAO_CARGO CLASSE_CARGO  \
# 554200   013****    ANALISTA TRIBUTARIO REC FEDERAL BRASIL            S
# 89831    011****         ASSISTENTE TECNICO-ADMINISTRATIVO            B
# 498180   011****  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL            S
# 286758   009****  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL            S
# 48711    000****    ANALISTA TRIBUTARIO REC FEDERAL BRASIL            S
#
# ...

# %%
df_estagio_ministerio_fazenda.value_counts("UORG_EXERCICIO").reset_index()
# Out:
#                                UORG_EXERCICIO  count
# 0            PROC-REG DA FAZ NAC NA 2A REGIAO     29
# 1          PROC DA FAZ NAC NO ESTADO DE GOIAS     26
# 2           PROC ESTADUAL DA FAZ NAC DO CEARA     25
# 3            PROC-REG DA FAZ NAC NA 5A REGIAO     22
# 4            PROC-REG DA FAZ NAC NA 1A REGIAO     19
# 5                 DIVISAO DE ASSUNTOS FISCAIS     18
# 6           DIVISAO DE DEFESA DE 2A INSTANCIA     16
# 7        SUBPROCURADORIA REGIONAL NA 6 REGIAO     15
# 8             PROC SEC DA FAZ NAC DE CAMPINAS     14
# 9       PROC SEC DA FAZ NAC DE S. JOSE CAMPOS     14
# 10           PROC-REG DA FAZ NAC NA 4A REGIAO     14
# 11      EQUIPE DE ATENDIMENTO AO CONTRIBUINTE     13
# 12      PROC DA FAZ NAC NO ESTADO DE MARANHAO     12
# 13         PROC DA FAZ NAC NO ESTADO DA BAHIA     12
# 14           PROC SEC DA FAZ NAC DE GUARULHOS     11
# 15     PROC DA FAZ NAC NO ESTADO DE TOCANTINS     10
# 16         PROC DA FAZ NAC NO ESTADO AMAZONAS      9
# ...

# %%
df_estagio_ministerio_fazenda.head(10)
# Out:
#      Id_SERVIDOR_PORTAL                         NOME             CPF  \
# 9             313302667          AARON MATHEUS MOURA  ***.470.823-**
# 76            310822592   ABDON BANDEIRA ANDRE FILHO  ***.884.724-**
# 144           312093404       ABEL DE AZEVEDO GARCIA  ***.240.960-**
# 168           311925156       ABEL ISACK DA SILVA SA  ***.982.643-**
# 262           310762883      ABGAIL PEREIRA DE SOUSA  ***.063.693-**
# 266           313077190         ABIA DOS SANTOS LIMA  ***.281.553-**
# 275           311033231  ABIDA HELLEN BARROS PEREIRA  ***.855.604-**
# 287           310939091  ABIGAIL CASTILHO DE ANDRADE  ***.695.451-**
# 306           313576587            ABIGAIL LUZ NOBRE  ***.352.213-**
# 322           311256876   ABILENE SILVESTRE FERREIRA  ***.598.322-**
#
#     MATRICULA DESCRICAO_CARGO CLASSE_CARGO  REFERENCIA_CARGO PADRAO_CARGO  \
# 9     033****        Inválido          NaN               0.0          NaN
# ...

# %%
# Use a função value_counts para contar a ocorrência de cada valor
contagem = df_cadastro['ORG_LOTACAO'].value_counts()

# Exiba a contagem
display(contagem)

# %%
display(type(contagem))

# %%
df_contagem = contagem.reset_index()
df_contagem.columns = ['Valor', 'Quantidade']

display(df_contagem)

# %%
# Crie um gráfico de barras
contagem.plot(kind='bar', color='skyblue')

# Adicione rótulos e título
plt.xlabel('Valores')
plt.ylabel('Quantidade')
plt.title('Contagem de Valores')

# Exiba o gráfico
plt.show()

# %%
# Crie um gráfico de barras interativo usando plotly express
fig = px.bar(df_contagem.head(100), x='Valor', y='Quantidade', color='Quantidade',
             labels={'Quantidade': 'Quantidade de Ocorrências'},
             title='Contagem de Valores - Gráfico Interativo')

# Exiba o gráfico interativo
fig.show()

fig.write_html('grafico_interativo_dados_siape_cadastro_total_.ORG_LOTACAO.html')

# %%
# Crie um gráfico de barras interativo usando plotly express
fig = px.bar(df_contagem.head(100), x='Valor', y='Quantidade', color='Valor',
             labels={'Quantidade': 'Quantidade de Ocorrências'},
             title='Contagem de Valores - Gráfico Interativo')

# Exiba o gráfico interativo
fig.show()

fig.write_html('grafico_interativo_dados_siape_cadastro_total_.ORG_LOTACAO.html')

# %%
display(px.colors.qualitative.Set3 )

# %%
import pandas as pd
import plotly.express as px

# Suponha que 'variavel' seja sua variável com os valores distintos
dados = {'variavel': ['A', 'B', 'A', 'C', 'B', 'A', 'A', 'C']}
df = pd.DataFrame(dados)

# Obtenha a contagem de valores
contagem = df['variavel'].value_counts().reset_index()
contagem.columns = ['Valor', 'Quantidade']

# Crie um gráfico de barras interativo usando plotly express
fig = px.bar(contagem, x='Valor', y='Quantidade', color='Quantidade',
             labels={'Quantidade': 'Quantidade de Ocorrências'},
             title='Contagem de Valores - Gráfico Interativo')

# Salve o gráfico em um arquivo HTML
fig.show()

# %%
import pandas as pd

# Exemplo de dados
dados = {
    'País': ['Brasil', 'Estados Unidos', 'China', 'Índia', 'Rússia', 'Indonésia', 'Paquistão', 'Bangladesh', 'Japão', 'México'],
    'População': [213993437, 331002651, 1444216107, 1380004385, 145934462, 273523615, 220892340, 164689383, 126476461, 128932753],
    'PenaDeMorte': ['Sim', 'Sim', 'Sim', 'Sim', 'Sim', 'Não', 'Sim', 'Sim', 'Não', 'Sim'],
}

# Criar o DataFrame
df = pd.DataFrame(dados)

# Exibir o DataFrame
print(df)
# Out:
#              País   População PenaDeMorte
# 0          Brasil   213993437         Sim
# 1  Estados Unidos   331002651         Sim
# 2           China  1444216107         Sim
# 3           Índia  1380004385         Sim
# 4          Rússia   145934462         Sim
# 5       Indonésia   273523615         Não
# 6       Paquistão   220892340         Sim
# 7      Bangladesh   164689383         Sim
# 8           Japão   126476461         Não
# 9          México   128932753         Sim

# %%
lista_resultado_filtro =

# %%
df[df['PenaDeMorte'] == 'Não']
# Out:
#         País  População PenaDeMorte
# 5  Indonésia  273523615         Não
# 8      Japão  126476461         Não

# %%
df[[False, True, True, True, True,False, False, False, False]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_14786/3580859421.py in ?()
# ----> 1 df[[False, True, True, True, True,False, False, False, False]]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, key)
#    3880             return self.where(key)
#    3881
#    3882         # Do we have a (boolean) 1d indexer?
#    3883         if com.is_bool_indexer(key):
# -> 3884             return self._getitem_bool_array(key)
#    3885
#    3886         # We are left with two options: a single key, and a collection of keys,
#    3887         # We interpret tuples as collections only for non-MultiIndex
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, key)
#    3930                 UserWarning,
#    3931                 stacklevel=find_stack_level(),
#    3932             )
#    3933         elif len(key) != len(self.index):
# ...
