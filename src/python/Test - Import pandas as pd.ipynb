# %%
import pandas as pd

# Substitua 'seu_arquivo.csv' pelo caminho do seu arquivo CSV
caminho_do_arquivo = '202311_Cadastro.csv'

# Carregando o arquivo CSV em um DataFrame do Pandas
dados = pd.read_csv(caminho_do_arquivo, encoding='iso-8859-2', sep=';')
# Out:
# /tmp/ipykernel_6025/3630915548.py:7: DtypeWarning: Columns (2,5,7,9,34,36,37,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados = pd.read_csv(caminho_do_arquivo, encoding='iso-8859-2', sep=';')

# %%
# Exibindo as primeiras linhas do DataFrame
#display(dados.head(3))
#display(dados.tail(2))

display(dados.sample(5, random_state=23432987))
# Out:
#         Id_SERVIDOR_PORTAL                             NOME             CPF  \
# 43764            313320075  ANA LUCIA ARAUJO MEIRELES LOPES  ***.982.192-**
# 87559            313145736              BENNY DA CRUZ MOURA  ***.435.651-**
# 227232           311506963     FELIPE GONCALVES DE CARVALHO  ***.930.207-**
# 741309                 -11                         Sigiloso             NaN
# 610539           310383094             ROGERIO PORTO DUARTE  ***.233.787-**
#
#        MATRICULA              DESCRICAO_CARGO CLASSE_CARGO  REFERENCIA_CARGO  \
# 43764    032****  MEDICO PROGRAMA MAIS MEDICO            1               0.0
# 87559    018****                 Sem informaç          NaN              -1.0
# 227232   015****                 TECNOLOGISTA            J               0.0
# 741309   002****                     Sigiloso          NaN               NaN
# 610539   014****                   ARQUIVISTA            E               0.0
#
# ...

# %%
display(dados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748596 entries, 0 to 748595
# Data columns (total 43 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Id_SERVIDOR_PORTAL                    748596 non-null  int64
#  1   NOME                                  748596 non-null  object
#  2   CPF                                   712000 non-null  object
#  3   MATRICULA                             748596 non-null  object
#  4   DESCRICAO_CARGO                       748596 non-null  object
#  5   CLASSE_CARGO                          569395 non-null  object
#  6   REFERENCIA_CARGO                      712000 non-null  float64
#  7   PADRAO_CARGO                          441081 non-null  object
#  8   NIVEL_CARGO                           712000 non-null  float64
#  9   SIGLA_FUNCAO                          748596 non-null  object
# ...
